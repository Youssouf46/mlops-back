# %%
#Load Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objs as go
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df =  pd.read_csv('my_dataset_merge.csv')

# %%
df.shape
# Out:
# (9815, 17)

# %%
df.head()
# Out:
#          date home_team    away_team  home_score  away_score tournament  \
# 0  2010-08-11   Albania   Uzbekistan           1           0   Friendly
# 1  2010-08-11   Algeria        Gabon           1           2   Friendly
# 2  2010-08-11    Angola      Uruguay           0           2   Friendly
# 3  2010-08-11   Armenia         Iran           1           3   Friendly
# 4  2010-08-11   Austria  Switzerland           0           1   Friendly
#
#          city   country  neutral  total_points_home  previous_points_home  \
# 0      Durrës   Albania    False              455.0                 455.0
# 1     Algiers   Algeria    False              759.0                 759.0
# 2      Lisbon  Portugal     True              357.0                 356.0
# 3     Yerevan   Armenia    False              318.0                 318.0
# 4  Klagenfurt   Austria    False              536.0                 536.0
#
#    rank_home  rank_change_home  total_points_away  previous_points_away  \
# 0       70.0              -1.0              351.0                 352.0
# 1       33.0               0.0              755.0                 755.0
# 2       87.0               1.0             1152.0                1152.0
# 3       96.0               0.0              517.0                 522.0
# 4       60.0               0.0              940.0                 940.0
#
#    rank_away  rank_change_away
# 0       88.0               1.0
# 1       34.0               0.0
# 2        6.0               0.0
# 3       65.0               1.0
# 4       17.0              -1.0

# %%
df.describe()
# Out:
#         home_score  away_score  total_points_home  previous_points_home  \
# count  9815.000000  9815.00000        9815.000000           9815.000000
# mean      1.546001     1.04921         795.764716            795.263194
# std       1.546935     1.23577         488.523834            488.056658
# min       0.000000     0.00000           2.000000              0.000000
# 25%       0.000000     0.00000         351.000000            351.000000
# 50%       1.000000     1.00000         749.000000            753.000000
# 75%       2.000000     2.00000        1222.000000           1220.000000
# max      17.000000    14.00000        2164.000000           2151.000000
#
#          rank_home  rank_change_home  total_points_away  previous_points_away  \
# count  9815.000000       9815.000000        9815.000000           9815.000000
# mean     80.798472          0.094040         776.311379            774.933244
# std      54.615337          5.449513         483.315404            483.188483
# min       1.000000        -73.000000           2.000000              0.000000
# 25%      33.000000         -1.000000         341.000000            341.000000
# 50%      74.000000          0.000000         718.000000            715.000000
# 75%     121.000000          1.000000        1188.000000           1186.305000
# max     211.000000         62.000000        2164.000000           2134.000000
#
#          rank_away  rank_change_away
# count  9815.000000       9815.000000
# mean     84.526949         -0.083953
# std      54.792114          5.881366
# min       1.000000        -73.000000
# 25%      38.000000         -1.000000
# 50%      78.000000          0.000000
# 75%     125.000000          1.000000
# max     211.000000         62.000000

# %%
df.hist(bins='auto', figsize=(14, 10))
# Out:
# array([[<Axes: title={'center': 'home_score'}>,
#         <Axes: title={'center': 'away_score'}>,
#         <Axes: title={'center': 'total_points_home'}>],
#        [<Axes: title={'center': 'previous_points_home'}>,
#         <Axes: title={'center': 'rank_home'}>,
#         <Axes: title={'center': 'rank_change_home'}>],
#        [<Axes: title={'center': 'total_points_away'}>,
#         <Axes: title={'center': 'previous_points_away'}>,
#         <Axes: title={'center': 'rank_away'}>],
#        [<Axes: title={'center': 'rank_change_away'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(14,5))
plt.title('away_score Distribution FIFA 20')
sns.distplot(a=df['away_score'], kde=True, bins=20)
plt.axvline(x=np.mean(df['away_score']),c='orange',label='Mean away_score of All Players')
plt.legend()

# %%
plt.figure(figsize=(14,5))
plt.title('away_score Distribution FIFA 20')
sns.distplot(a=df['home_score'], kde=True, bins=20)
plt.axvline(x=np.mean(df['home_score']),c='orange',label='Mean away_score of All Players')
plt.legend()

# %%
top_point = df.sort_values(by=["total_points_home"], ascending=False)
top_point.head(10)
# Out:
#             date home_team away_team  home_score  away_score      tournament  \
# 6458  2018-07-10    France   Belgium           1           0  FIFA World Cup
# 6461  2018-07-15    France   Croatia           4           2  FIFA World Cup
# 6455  2018-07-06    Brazil   Belgium           1           2  FIFA World Cup
# 6449  2018-07-02    Brazil    Mexico           2           0  FIFA World Cup
# 6450  2018-07-02   Belgium     Japan           3           2  FIFA World Cup
# 6460  2018-07-14   Belgium   England           2           0  FIFA World Cup
# 6459  2018-07-11   Croatia   England           2           1  FIFA World Cup
# 6448  2018-07-01   Croatia   Denmark           1           1  FIFA World Cup
# 6454  2018-07-06   Uruguay    France           0           2  FIFA World Cup
# 6452  2018-07-03  Colombia   England           1           1  FIFA World Cup
#
#                   city country  neutral  total_points_home  \
# 6458  Saint Petersburg  Russia     True             2164.0
# 6461            Moscow  Russia     True             2164.0
# 6455             Kazan  Russia     True             2160.0
# 6449            Samara  Russia     True             2160.0
# 6450     Rostov-on-Don  Russia     True             2124.0
# 6460  Saint Petersburg  Russia     True             2124.0
# 6459            Moscow  Russia     True             2036.0
# 6448   Nizhny Novgorod  Russia     True             2036.0
# 6454   Nizhny Novgorod  Russia     True             2017.0
# 6452            Moscow  Russia     True             1998.0
#
#       previous_points_home  rank_home  rank_change_home  total_points_away  \
# 6458                2134.0        2.0              -2.0             2124.0
# 6461                2134.0        2.0              -2.0             2036.0
# 6455                2151.0        4.0               1.0             2124.0
# 6449                2151.0        4.0               1.0             2041.0
# 6450                2098.0        5.0              -1.0             1816.0
# 6460                2098.0        5.0              -1.0             2099.0
# 6459                1990.0       12.0              -6.0             2099.0
# 6448                1990.0       12.0              -6.0             2014.0
# 6454                1991.0       14.0              -3.0             2164.0
# 6452                2005.0       17.0               3.0             2099.0
#
#       previous_points_away  rank_away  rank_change_away
# 6458                2098.0        5.0              -1.0
# 6461                1990.0       12.0              -6.0
# 6455                2098.0        5.0              -1.0
# 6449                1996.0       10.0              -5.0
# 6450                1773.0       41.0              -7.0
# 6460                2074.0        7.0              -2.0
# 6459                2074.0        7.0              -2.0
# 6448                1992.0       15.0              -1.0
# 6454                2134.0        2.0              -2.0
# 6452                2074.0        7.0              -2.0

# %%
top_points = top_point.drop_duplicates(subset=["home_team"])
top_points.head(10)
# Out:
#             date  home_team      away_team  home_score  away_score  \
# 6458  2018-07-10     France        Belgium           1           0
# 6455  2018-07-06     Brazil        Belgium           1           2
# 6450  2018-07-02    Belgium          Japan           3           2
# 6459  2018-07-11    Croatia        England           2           1
# 6454  2018-07-06    Uruguay         France           0           2
# 6452  2018-07-03   Colombia        England           1           1
# 6451  2018-07-03     Sweden    Switzerland           1           0
# 510   2011-02-09      Spain       Colombia           1           0
# 3970  2015-06-10    Germany  United States           1           2
# 9709  2022-09-23  Argentina       Honduras           3           0
#
#           tournament              city        country  neutral  \
# 6458  FIFA World Cup  Saint Petersburg         Russia     True
# 6455  FIFA World Cup             Kazan         Russia     True
# 6450  FIFA World Cup     Rostov-on-Don         Russia     True
# 6459  FIFA World Cup            Moscow         Russia     True
# 6454  FIFA World Cup   Nizhny Novgorod         Russia     True
# 6452  FIFA World Cup            Moscow         Russia     True
# 6451  FIFA World Cup  Saint Petersburg         Russia     True
# 510         Friendly            Madrid          Spain    False
# 3970        Friendly           Cologne        Germany    False
# 9709        Friendly     Miami Gardens  United States     True
#
#       total_points_home  previous_points_home  rank_home  rank_change_home  \
# 6458            2164.00               2134.00        2.0              -2.0
# 6455            2160.00               2151.00        4.0               1.0
# 6450            2124.00               2098.00        5.0              -1.0
# 6459            2036.00               1990.00       12.0              -6.0
# 6454            2017.00               1991.00       14.0              -3.0
# 6452            1998.00               2005.00       17.0               3.0
# 6451            1955.00               1954.00       21.0              -1.0
# 510             1887.00               1887.00        1.0               0.0
# 3970            1775.00               1687.00        1.0               0.0
# 9709            1770.65               1770.65        3.0               0.0
#
#       total_points_away  previous_points_away  rank_away  rank_change_away
# 6458            2124.00               2098.00        5.0              -1.0
# 6455            2124.00               2098.00        5.0              -1.0
# 6450            1816.00               1773.00       41.0              -7.0
# 6459            2099.00               2074.00        7.0              -2.0
# 6454            2164.00               2134.00        2.0              -2.0
# 6452            2099.00               2074.00        7.0              -2.0
# 6451            2087.00               2065.00        8.0              -2.0
# 510              558.00                558.00       50.0               2.0
# 3970             823.00                825.00       27.0              -1.0
# 9709            1299.69               1299.69       80.0               0.0
